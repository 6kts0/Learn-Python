# %% [markdown]
# # **yfinance use case in action**
# ------------------------------------------
# # **Printing raw dataset with default dictionairy formatting**

# %%
# Import main and dependant libraries
import yfinance as yf
import pandas as pd
import csv

# CONSTANT POINTER TO SORTED DATA
RKLB_DATA = "rklb_info.csv"

# Initialize ticker/stock
ticker = "RKLB"
stock = yf.Ticker(ticker)

# Fetch raw stock data
si = stock.info

print(si)
# Out:
# {'address1': '3881 McGowen Street', 'city': 'Long Beach', 'state': 'CA', 'zip': '90808', 'country': 'United States', 'phone': '714 465 5737', 'website': 'https://rocketlabcorp.com', 'industry': 'Aerospace & Defense', 'industryKey': 'aerospace-defense', 'industryDisp': 'Aerospace & Defense', 'sector': 'Industrials', 'sectorKey': 'industrials', 'sectorDisp': 'Industrials', 'longBusinessSummary': 'Rocket Lab Corporation, a space company, provides launch services and space systems solutions in the United States, Canada, Japan, and internationally. The company provides launch services, spacecraft design services, spacecraft components, spacecraft manufacturing, and other spacecraft and on-orbit management solutions; and constellation management services, as well as designs and manufactures small and medium-class rockets. It also designs, manufactures, and sells Electron, an orbital small launch vehicle for small spacecraft launch services, as well as develops Neutron launch vehicles for large constellation deployments, interplanetary missions and potentially for human spaceflight. In addition, the company designs and manufactures a range of components and subsystems for its launch vehicles and spacecraft. It serves commercial, aerospace prime contractors, and government customers. Rocket Lab Corporation was founded in 2006 and is headquartered in Long Beach, California.', 'fullTimeEmployees': 2100, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Peter  Beck', 'age': 47, 'title': 'Founder, Chairman, President & CEO', 'yearBorn': 1977, 'fiscalYear': 2024, 'totalPay': 1947285, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Adam C. Spice', 'age': 55, 'title': 'CFO & Treasurer', 'yearBorn': 1969, 'fiscalYear': 2024, 'totalPay': 733040, 'exercisedValue': 0, 'unexercisedValue': 124865872}, {'maxAge': 1, 'name': 'Mr. Frank  Klein', 'age': 51, 'title': 'Chief Operations Officer', 'yearBorn': 1973, 'fiscalYear': 2024, 'totalPay': 584029, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Arjun L. Kampani J.D.', 'age': 52, 'title': 'Senior VP, General Counsel & Corporate Secretary', 'yearBorn': 1972, 'fiscalYear': 2024, 'totalPay': 654466, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Morgan  Bailey Connaughton', 'title': 'Vice President of Marketing & Communications', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Connie  Lundgren', 'title': 'Vice President of People & Culture', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': "Mr. Shaun  O'Donnell", 'age': 46, 'title': 'Chief Engineer of Special Programs', 'yearBorn': 1978, 'fiscalYear': 2024, 'totalPay': 326541, 'exercisedValue': 0, 'unexercisedValue': 4620073}, {'maxAge': 1, 'name': 'Mr. Ehson  Mosleh', 'title': 'Space Systems Chief Engineer', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Murielle  Baker', 'title': 'Senior Communications Manager', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Stephen N. Ananias', 'age': 49, 'title': 'Vice President of Finance', 'yearBorn': 1975, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}], 'auditRisk': 6, 'boardRisk': 9, 'compensationRisk': 10, 'shareHolderRightsRisk': 9, 'overallRisk': 10, 'governanceEpochDate': 1764547200, 'compensationAsOfEpochDate': 1735603200, 'executiveTeam': [], 'maxAge': 86400, 'priceHint': 2, 'previousClose': 40.370003, 'open': 40.56, 'dayLow': 40.42, 'dayHigh': 42.9896, 'regularMarketPreviousClose': 40.370003, 'regularMarketOpen': 40.56, 'regularMarketDayLow': 40.42, 'regularMarketDayHigh': 42.9896, 'payoutRatio': 0.0, 'beta': 2.174, 'forwardPE': -182.17392, 'volume': 13389276, 'regularMarketVolume': 13389276, 'averageVolume': 21665888, 'averageVolume10days': 15442210, 'averageDailyVolume10Day': 15442210, 'bid': 41.77, 'ask': 42.0, 'bidSize': 30, 'askSize': 30, 'marketCa ...

# %% [markdown]
# #

# %% [markdown]
# # **Displaying the first 7 rows of the dataset**

# %%
# Fetch information for the chosen stock
stock_info = stock.info

# Convert the default dictionairy format to a dataframe
# Every dictionairy key will create a new row in the dataframe
stock_info_df = pd.DataFrame.from_dict(stock_info, orient='index', columns=['Value'])
stock_info_df.to_csv(RKLB_DATA)
rklb_info_read = pd.read_csv(RKLB_DATA, index_col=0)

# Print the first 7 lines of data
print(rklb_info_read.head(8))
# Out:
#                               Value
# address1        3881 McGowen Street
# city                     Long Beach
# state                            CA
# zip                           90808
# country               United States
# phone                  714 465 5737
# website   https://rocketlabcorp.com
# industry        Aerospace & Defense

# %% [markdown]
# # **Printing specific data by pre-selecting dictionairy keys**

# %%
print(rklb_info_read.loc[['displayName', 'symbol', 'industry', 'regularMarketOpen', 'allTimeHigh', 'allTimeLow', 'fiftyDayAverage', 'profitMargins', 'marketCap']])
# Out:
#                                  Value
# displayName                 Rocket Lab
# symbol                            RKLB
# industry           Aerospace & Defense
# regularMarketOpen                40.56
# allTimeHigh                      73.97
# allTimeLow                        3.47
# fiftyDayAverage                54.5429
# profitMargins                 -0.35639
# marketCap                  22381150208
